# %% [markdown]
# # Best Places To Hangout In Mumbai

# %% [markdown]
# ## Introduction
# ##### ABC is a company based in Toronto for tourism currently it works on a project to organize an event for 5 days for a group of artists from all over the world.The company has to put a good program, including a hotel of residence, a hall for meetings, places of landscape to visit, stores for shopping, restaurants and cafes. So the company’s purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.

# %% [markdown]
# ## Data Description
# ##### The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ### Importing Libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.10
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          90 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.10
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %% [markdown]
# ### Foursquare Details

# %%
ClIENT_ID = 'AACVJZ5QQJBAAIRAQ1F41HBULHIMT1JVS4PDWD2TD1VGJIKV' # your Foursquare ID
ClIENT_SECRET = '5201AOLYTAS41XZPRYJM4XB0EAXKEEAXUGY2GETOTF2L3UDJ' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: AACVJZ5QQJBAAIRAQ1F41HBULHIMT1JVS4PDWD2TD1VGJIKV
# Foursquare_Secret:5201AOLYTAS41XZPRYJM4XB0EAXKEEAXUGY2GETOTF2L3UDJ

# %% [markdown]
# ### Getting Co-Ordinates

# %%
# define the city and get its latitude & longitude 
city = 'Mumbai'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 18.9387711 72.8353355

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AACVJZ5QQJBAAIRAQ1F41HBULHIMT1JVS4PDWD2TD1VGJIKV&client_secret=5201AOLYTAS41XZPRYJM4XB0EAXKEEAXUGY2GETOTF2L3UDJ&ll=18.9387711,72.8353355&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                   name  \
# 0  4bcf4de40ffdce72215fb2c0        Residency Hotel
# 1  4e135a03a809291902c7d32f  Hotel Traveller’s Inn
# 2  4cbc460f9552b60c8d81e48b      City Palace Hotel
# 3  4ffaf206e4b0a0306dd1271d      Hotel City Palace
# 4  5321eed6498e273e35971c04            sheel hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1564033918    False
# 1  [{'id': '4bf58dd8d48988d1f8931735', 'name': 'B...  v-1564033918    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1564033918    False
# 3                                                 []  v-1564033918    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1564033918    False
#
#                                     location.address  location.lat  \
# 0  26, Corner of D.N. Road and Rustom Sidhwa Marg...     18.934978
# 1                               26, ADI Marzban Path     18.936039
# 2                                                NaN     18.938970
# 3                                           Near CST     18.938474
# 4                                                NaN     18.938211
#
#    location.lng                            location.labeledLatLngs  \
# 0     72.833481  [{'label': 'display', 'lat': 18.93497786680689...
# 1     72.838000  [{'label': 'display', 'lat': 18.93603902855253...
# 2     72.835610  [{'label': 'display', 'lat': 18.93897, 'lng': ...
# 3     72.834599  [{'label': 'display', 'lat': 18.93847362379592...
# 4     72.835725  [{'label': 'display', 'lat': 18.93821144054106...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                465              400001          IN        Mumbai
# 1                413              400001          IN        Mumbai
# 2                 36                 NaN          IN           NaN
# 3                 84                 NaN          IN        Mumbai
# 4                 74                 NaN          IN           NaN
#
#   location.state location.country  \
# 0    Mahārāshtra            India
# 1    Mahārāshtra            India
# 2            NaN            India
# 3    Mahārāshtra            India
# 4            NaN            India
#
#                            location.formattedAddress  \
# 0  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 1  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 2                                            [India]
# 3             [Near CST, Mumbai, Mahārāshtra, India]
# 4                                            [India]
#
#                           location.crossStreet
# 0                                          NaN
# 1  Behind Cafe Universal, Ballard Estate, Fort
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN

# %% [markdown]
# ### Clean the Data

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                     name       categories  \
# 0        Residency Hotel            Hotel
# 1  Hotel Traveller’s Inn  Bed & Breakfast
# 2      City Palace Hotel            Hotel
# 3      Hotel City Palace             None
# 4            sheel hotel            Hotel
#
#                                              address        lat        lng  \
# 0  26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                               26, ADI Marzban Path  18.936039  72.838000
# 2                                                NaN  18.938970  72.835610
# 3                                           Near CST  18.938474  72.834599
# 4                                                NaN  18.938211  72.835725
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 18.93497786680689...       465     400001  IN
# 1  [{'label': 'display', 'lat': 18.93603902855253...       413     400001  IN
# 2  [{'label': 'display', 'lat': 18.93897, 'lng': ...        36        NaN  IN
# 3  [{'label': 'display', 'lat': 18.93847362379592...        84        NaN  IN
# 4  [{'label': 'display', 'lat': 18.93821144054106...        74        NaN  IN
#
#      city        state country  \
# 0  Mumbai  Mahārāshtra   India
# 1  Mumbai  Mahārāshtra   India
# 2     NaN          NaN   India
# 3  Mumbai  Mahārāshtra   India
# 4     NaN          NaN   India
#
#                                     formattedAddress  \
# 0  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 1  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 2                                            [India]
# 3             [Near CST, Mumbai, Mahārāshtra, India]
# 4                                            [India]
#
#                                    crossStreet                        id
# 0                                          NaN  4bcf4de40ffdce72215fb2c0
# 1  Behind Cafe Universal, Ballard Estate, Fort  4e135a03a809291902c7d32f
# 2                                          NaN  4cbc460f9552b60c8d81e48b
# 3                                          NaN  4ffaf206e4b0a0306dd1271d
# 4                                          NaN  5321eed6498e273e35971c04

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','id'], axis=1)
clean_dataframe2
# Out:
#                         name                                categories  \
# 0            Residency Hotel                                     Hotel
# 1      Hotel Traveller’s Inn                           Bed & Breakfast
# 2          City Palace Hotel                                     Hotel
# 3          Hotel City Palace                                      None
# 4                sheel hotel                                     Hotel
# 5       Hotel Fountain Plaza                         Indian Restaurant
# 6              Hotel Windsor                                    Hostel
# 7        Hotel Landmark Fort                           Bed & Breakfast
# 8               hotel kalapi                                     Motel
# 9         Colaba Grand Hotel                                 Hotel Bar
# 10     Hotel Landmark Annexe                                     Hotel
# 11        Hotel Ankitakshita                                     Hotel
# 12            Hotel Arkshita                               Snack Place
# 13        Hotel Anand Bhuvan                      Fast Food Restaurant
# 14              Hotel Ashoka                         Indian Restaurant
# 15              Hotel Outram                                     Hotel
# 16             Hotel Dolphin                                     Hotel
# 17             Welcome Hotel                                     Motel
# 18    hotel golden palm fort                                Hotel Pool
# 19     landmark hotel mumbai  Residential Building (Apartment / Condo)
# 20  A.k. International Hotel                                     Hotel
# 21              Deluxe Hotel                       Housing Development
# 22            Benazeer Hotel                                     Hotel
# 23              Cenora Hotel                          Asian Restaurant
# 24           Whatson's Hotel                                     Hotel
# 25      Mumbai Hotels, India                                     Hotel
# 26          New Anand Bhavan                      Fast Food Restaurant
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                26, ADI Marzban Path  18.936039  72.838000
# 2                                                 NaN  18.938970  72.835610
# 3                                            Near CST  18.938474  72.834599
# 4                                                 NaN  18.938211  72.835725
# 5             panthaky house, Raghunath dadaji street  18.935671  72.834030
# 6                                          Kumptha 10  18.936808  72.838327
# 7                                  249 P D Mello Road  18.938528  72.837998
# 8                                                 NaN  18.938184  72.837802
# 9                                              Colaba  18.939656  72.836457
# 10                                                NaN  18.938030  72.838844
# 11                                                NaN  18.935698  72.837123
# 12                                                NaN  18.935647  72.837311
# 13                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 14                                                NaN  18.942741  72.834501
# 15                                                NaN  18.936418  72.831732
# 16                                       327,SBS Road  18.934567  72.836942
# 17                        257 Shahid Bhagat Singh Rd.  18.937703  72.837467
# 18                                               Fort  18.933103  72.834628
# 19                                                NaN  18.938465  72.838217
# 20                                                NaN  18.935867  72.837875
# 21                       287 Shahid Bhagat Singh Road  18.935690  72.837398
# 22                                   16 Gunbow Street  18.935140  72.833948
# 23                                                NaN  18.934916  72.836969
# 24                                               Fort  18.934662  72.836778
# 25                                             Mumbai  18.939616  72.835665
# 26                                        Sheri House  18.934656  72.834848
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 2         NaN          NaN
# 3         NaN  Mahārāshtra
# 4         NaN          NaN
# 5         NaN  Mahārāshtra
# 6         NaN  Mahārāshtra
# 7      400001  Mahārāshtra
# 8         NaN          NaN
# 9         NaN  Mahārāshtra
# 10     400001  Mahārāshtra
# 11     400023  Mahārāshtra
# 12        NaN          NaN
# 13     400001  Mahārāshtra
# 14        NaN          NaN
# 15        NaN          NaN
# 16        NaN  Mahārāshtra
# 17        NaN  Mahārāshtra
# 18        NaN  Mahārāshtra
# 19        NaN          NaN
# 20        NaN          NaN
# 21     400001  Mahārāshtra
# 22     400001  Mahārāshtra
# 23        NaN          NaN
# 24        NaN  Mahārāshtra
# 25        NaN  Mahārāshtra
# 26     400023  Mahārāshtra

# %%
clean_dataframe2['postalCode'] = clean_dataframe2['postalCode'].replace(np.nan, 400101)
clean_dataframe2['state'] = clean_dataframe2['state'].replace('Mahārāshtra','Maharashtra')
clean_dataframe2['state'] = clean_dataframe2['state'].replace(np.nan,'Maharashtra')
clean_dataframe2['address'] = clean_dataframe2['address'].replace(np.nan,'South Mumbai')
clean_dataframe2
# Out:
#                         name                                categories  \
# 0            Residency Hotel                                     Hotel
# 1      Hotel Traveller’s Inn                           Bed & Breakfast
# 2          City Palace Hotel                                     Hotel
# 3          Hotel City Palace                                      None
# 4                sheel hotel                                     Hotel
# 5       Hotel Fountain Plaza                         Indian Restaurant
# 6              Hotel Windsor                                    Hostel
# 7        Hotel Landmark Fort                           Bed & Breakfast
# 8               hotel kalapi                                     Motel
# 9         Colaba Grand Hotel                                 Hotel Bar
# 10     Hotel Landmark Annexe                                     Hotel
# 11        Hotel Ankitakshita                                     Hotel
# 12            Hotel Arkshita                               Snack Place
# 13        Hotel Anand Bhuvan                      Fast Food Restaurant
# 14              Hotel Ashoka                         Indian Restaurant
# 15              Hotel Outram                                     Hotel
# 16             Hotel Dolphin                                     Hotel
# 17             Welcome Hotel                                     Motel
# 18    hotel golden palm fort                                Hotel Pool
# 19     landmark hotel mumbai  Residential Building (Apartment / Condo)
# 20  A.k. International Hotel                                     Hotel
# 21              Deluxe Hotel                       Housing Development
# 22            Benazeer Hotel                                     Hotel
# 23              Cenora Hotel                          Asian Restaurant
# 24           Whatson's Hotel                                     Hotel
# 25      Mumbai Hotels, India                                     Hotel
# 26          New Anand Bhavan                      Fast Food Restaurant
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                26, ADI Marzban Path  18.936039  72.838000
# 2                                        South Mumbai  18.938970  72.835610
# 3                                            Near CST  18.938474  72.834599
# 4                                        South Mumbai  18.938211  72.835725
# 5             panthaky house, Raghunath dadaji street  18.935671  72.834030
# 6                                          Kumptha 10  18.936808  72.838327
# 7                                  249 P D Mello Road  18.938528  72.837998
# 8                                        South Mumbai  18.938184  72.837802
# 9                                              Colaba  18.939656  72.836457
# 10                                       South Mumbai  18.938030  72.838844
# 11                                       South Mumbai  18.935698  72.837123
# 12                                       South Mumbai  18.935647  72.837311
# 13                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 14                                       South Mumbai  18.942741  72.834501
# 15                                       South Mumbai  18.936418  72.831732
# 16                                       327,SBS Road  18.934567  72.836942
# 17                        257 Shahid Bhagat Singh Rd.  18.937703  72.837467
# 18                                               Fort  18.933103  72.834628
# 19                                       South Mumbai  18.938465  72.838217
# 20                                       South Mumbai  18.935867  72.837875
# 21                       287 Shahid Bhagat Singh Road  18.935690  72.837398
# 22                                   16 Gunbow Street  18.935140  72.833948
# 23                                       South Mumbai  18.934916  72.836969
# 24                                               Fort  18.934662  72.836778
# 25                                             Mumbai  18.939616  72.835665
# 26                                        Sheri House  18.934656  72.834848
#
#    postalCode        state
# 0      400001  Maharashtra
# 1      400001  Maharashtra
# 2      400101  Maharashtra
# 3      400101  Maharashtra
# 4      400101  Maharashtra
# 5      400101  Maharashtra
# 6      400101  Maharashtra
# 7      400001  Maharashtra
# 8      400101  Maharashtra
# 9      400101  Maharashtra
# 10     400001  Maharashtra
# 11     400023  Maharashtra
# 12     400101  Maharashtra
# 13     400001  Maharashtra
# 14     400101  Maharashtra
# 15     400101  Maharashtra
# 16     400101  Maharashtra
# 17     400101  Maharashtra
# 18     400101  Maharashtra
# 19     400101  Maharashtra
# 20     400101  Maharashtra
# 21     400001  Maharashtra
# 22     400001  Maharashtra
# 23     400101  Maharashtra
# 24     400101  Maharashtra
# 25     400101  Maharashtra
# 26     400023  Maharashtra

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
hotel_df=clean_dataframe3

# %%
hotel_df
# Out:
#                         name                                categories  \
# 0            Residency Hotel                                     Hotel
# 1      Hotel Traveller’s Inn                           Bed & Breakfast
# 2          City Palace Hotel                                     Hotel
# 4                sheel hotel                                     Hotel
# 5       Hotel Fountain Plaza                         Indian Restaurant
# 6              Hotel Windsor                                    Hostel
# 7        Hotel Landmark Fort                           Bed & Breakfast
# 8               hotel kalapi                                     Motel
# 9         Colaba Grand Hotel                                 Hotel Bar
# 10     Hotel Landmark Annexe                                     Hotel
# 11        Hotel Ankitakshita                                     Hotel
# 12            Hotel Arkshita                               Snack Place
# 13        Hotel Anand Bhuvan                      Fast Food Restaurant
# 14              Hotel Ashoka                         Indian Restaurant
# 15              Hotel Outram                                     Hotel
# 16             Hotel Dolphin                                     Hotel
# 17             Welcome Hotel                                     Motel
# 18    hotel golden palm fort                                Hotel Pool
# 19     landmark hotel mumbai  Residential Building (Apartment / Condo)
# 20  A.k. International Hotel                                     Hotel
# 21              Deluxe Hotel                       Housing Development
# 22            Benazeer Hotel                                     Hotel
# 23              Cenora Hotel                          Asian Restaurant
# 24           Whatson's Hotel                                     Hotel
# 25      Mumbai Hotels, India                                     Hotel
# 26          New Anand Bhavan                      Fast Food Restaurant
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                26, ADI Marzban Path  18.936039  72.838000
# 2                                        South Mumbai  18.938970  72.835610
# 4                                        South Mumbai  18.938211  72.835725
# 5             panthaky house, Raghunath dadaji street  18.935671  72.834030
# 6                                          Kumptha 10  18.936808  72.838327
# 7                                  249 P D Mello Road  18.938528  72.837998
# 8                                        South Mumbai  18.938184  72.837802
# 9                                              Colaba  18.939656  72.836457
# 10                                       South Mumbai  18.938030  72.838844
# 11                                       South Mumbai  18.935698  72.837123
# 12                                       South Mumbai  18.935647  72.837311
# 13                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 14                                       South Mumbai  18.942741  72.834501
# 15                                       South Mumbai  18.936418  72.831732
# 16                                       327,SBS Road  18.934567  72.836942
# 17                        257 Shahid Bhagat Singh Rd.  18.937703  72.837467
# 18                                               Fort  18.933103  72.834628
# 19                                       South Mumbai  18.938465  72.838217
# 20                                       South Mumbai  18.935867  72.837875
# 21                       287 Shahid Bhagat Singh Road  18.935690  72.837398
# 22                                   16 Gunbow Street  18.935140  72.833948
# 23                                       South Mumbai  18.934916  72.836969
# 24                                               Fort  18.934662  72.836778
# 25                                             Mumbai  18.939616  72.835665
# 26                                        Sheri House  18.934656  72.834848
#
#    postalCode        state
# 0      400001  Maharashtra
# 1      400001  Maharashtra
# 2      400101  Maharashtra
# 4      400101  Maharashtra
# 5      400101  Maharashtra
# 6      400101  Maharashtra
# 7      400001  Maharashtra
# 8      400101  Maharashtra
# 9      400101  Maharashtra
# 10     400001  Maharashtra
# 11     400023  Maharashtra
# 12     400101  Maharashtra
# 13     400001  Maharashtra
# 14     400101  Maharashtra
# 15     400101  Maharashtra
# 16     400101  Maharashtra
# 17     400101  Maharashtra
# 18     400101  Maharashtra
# 19     400101  Maharashtra
# 20     400101  Maharashtra
# 21     400001  Maharashtra
# 22     400001  Maharashtra
# 23     400101  Maharashtra
# 24     400101  Maharashtra
# 25     400101  Maharashtra
# 26     400023  Maharashtra

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AACVJZ5QQJBAAIRAQ1F41HBULHIMT1JVS4PDWD2TD1VGJIKV&client_secret=5201AOLYTAS41XZPRYJM4XB0EAXKEEAXUGY2GETOTF2L3UDJ&ll=18.9387711,72.8353355&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                          id                             name  \
# 0  4c9174ec238c6dcb067ec055               Priyadarshini Park
# 1  4c21b5b5502b952168d36d21         Peninsula Corporate Park
# 2  511e3da9e4b092d8057a44b6  Harish Mahindra Children's Park
# 3  52f2771d11d2afc107a8206d        Traditions at Reagan Park
# 4  5b430c7f2b274a002c36a513                      Rivali Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1564036441    False
# 1  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1564036441    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1564036441    False
# 3  [{'id': '5267e4d9e4b0ec79466e48c6', 'name': 'C...  v-1564036441    False
# 4  [{'id': '5032885091d4c4b30a586d66', 'name': 'R...  v-1564036441    False
#
#                                     location.address  location.lat  \
# 0                                    Nepean Sea Road     18.957515
# 1                                        Lower Parel     18.998626
# 2           Breach Candy, Behind American Counsulate     18.914867
# 3                                1176 Kingwood Drive     18.949804
# 4  Rivali Park, Western Express Highway,Borivali ...     18.929599
#
#    location.lng                            location.labeledLatLngs  \
# 0     72.799614  [{'label': 'display', 'lat': 18.95751519120163...
# 1     72.825408  [{'label': 'display', 'lat': 18.99862608309867...
# 2     72.823688  [{'label': 'display', 'lat': 18.91486679408915...
# 3     72.834699  [{'label': 'display', 'lat': 18.94980408771263...
# 4     72.828181  [{'label': 'display', 'lat': 18.92959945134227...
#
#    location.distance location.postalCode location.cc location.city  \
# 0               4301              400006          IN        Mumbai
# 1               6744              400013          IN        Mumbai
# 2               2930              400026          IN        Mumbai
# 3               1230               46123          IN          Avon
# 4               1268              400066          IN           NaN
#
#   location.state location.country  \
# 0    Mahārāshtra            India
# 1    Mahārāshtra            India
# 2    Mahārāshtra            India
# 3        Indiana            India
# 4    Mahārāshtra            India
#
#                            location.formattedAddress  location.crossStreet  \
# 0  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...                   NaN
# 1  [Lower Parel (G K Marg), Mumbai 400013, Mahārā...              G K Marg
# 2  [Breach Candy, Behind American Counsulate (Bhu...  Bhulabhai Desai Road
# 3  [1176 Kingwood Drive, Avon 46123, Indiana, India]                   NaN
# 4  [Rivali Park, Western Express Highway,Borivali...                   NaN
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                               name          categories  \
# 0               Priyadarshini Park                Park
# 1         Peninsula Corporate Park            Building
# 2  Harish Mahindra Children's Park                Park
# 3        Traditions at Reagan Park          Conference
# 4                      Rivali Park  Real Estate Office
#
#                                              address        lat        lng  \
# 0                                    Nepean Sea Road  18.957515  72.799614
# 1                                        Lower Parel  18.998626  72.825408
# 2           Breach Candy, Behind American Counsulate  18.914867  72.823688
# 3                                1176 Kingwood Drive  18.949804  72.834699
# 4  Rivali Park, Western Express Highway,Borivali ...  18.929599  72.828181
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 18.95751519120163...      4301     400006  IN
# 1  [{'label': 'display', 'lat': 18.99862608309867...      6744     400013  IN
# 2  [{'label': 'display', 'lat': 18.91486679408915...      2930     400026  IN
# 3  [{'label': 'display', 'lat': 18.94980408771263...      1230      46123  IN
# 4  [{'label': 'display', 'lat': 18.92959945134227...      1268     400066  IN
#
#      city        state country  \
# 0  Mumbai  Mahārāshtra   India
# 1  Mumbai  Mahārāshtra   India
# 2  Mumbai  Mahārāshtra   India
# 3    Avon      Indiana   India
# 4     NaN  Mahārāshtra   India
#
#                                     formattedAddress           crossStreet  \
# 0  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...                   NaN
# 1  [Lower Parel (G K Marg), Mumbai 400013, Mahārā...              G K Marg
# 2  [Breach Candy, Behind American Counsulate (Bhu...  Bhulabhai Desai Road
# 3  [1176 Kingwood Drive, Avon 46123, Indiana, India]                   NaN
# 4  [Rivali Park, Western Express Highway,Borivali...                   NaN
#
#                          id
# 0  4c9174ec238c6dcb067ec055
# 1  4c21b5b5502b952168d36d21
# 2  511e3da9e4b092d8057a44b6
# 3  52f2771d11d2afc107a8206d
# 4  5b430c7f2b274a002c36a513

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                name                                categories  \
# 0                Priyadarshini Park                                      Park
# 1          Peninsula Corporate Park                                  Building
# 2   Harish Mahindra Children's Park                                      Park
# 3         Traditions at Reagan Park                                Conference
# 4                       Rivali Park                        Real Estate Office
# 5                       Park Avenue                            Clothing Store
# 6                       Park Avenue                               Men's Store
# 7              Hotel Residency Park                                     Hotel
# 8                  One Avighna Park                       Housing Development
# 9              Hotel Residency Park                                     Hotel
# 10                      Bhakti Park                       Housing Development
# 11                     Badhwar Park                       Housing Development
# 12          Peninsula Business Park                           Coworking Space
# 13                     Badhwar Park                              Neighborhood
# 14              Kanha National Park                      Other Great Outdoors
# 15                     Park Shilton                                Restaurant
# 16                Kamala Nehru Park                       Monument / Landmark
# 17     Bhakti Park Monorail Station                        Light Rail Station
# 18                     Traffic Park                                      Park
# 19      China Garden Shivaji Park ¤                        Chinese Restaurant
# 20                      saifee park  Residential Building (Apartment / Condo)
# 21                     Badhwar Park  Residential Building (Apartment / Condo)
# 22                        Park View  Residential Building (Apartment / Condo)
# 23                        Hill Park  Residential Building (Apartment / Condo)
# 24                  Land's End Park                                      Park
# 25              Saifee Burhani Park  Residential Building (Apartment / Condo)
# 26                     Shivaji Park                                Playground
# 27                      Nirmal Park                     Outdoors & Recreation
# 28             Harish Mahindra Park                                Playground
# 29                Park Avenue Women                             Women's Store
#
#                                               address        lat        lng  \
# 0                                     Nepean Sea Road  18.957515  72.799614
# 1                                         Lower Parel  18.998626  72.825408
# 2            Breach Candy, Behind American Counsulate  18.914867  72.823688
# 3                                 1176 Kingwood Drive  18.949804  72.834699
# 4   Rivali Park, Western Express Highway,Borivali ...  18.929599  72.828181
# 5                             in High Street Phoenix,  18.996986  72.826677
# 6   Shop No. 32/34, Churchgate House, Veer Nariman...  18.920214  72.830151
# 7                                                 NaN  18.953120  72.835175
# 8                           Mahadev Palav Marg, Parel  18.994041  72.834806
# 9                                                 NaN  18.953255  72.835320
# 10                                   Near Imax Adlabs  19.027670  72.880010
# 11                                     Wodehouse Road  18.919160  72.826648
# 12                              Karamveer Yadav Chowk  18.998868  72.828123
# 13                                                NaN  18.921100  72.827300
# 14                                                NaN  18.923037  72.822986
# 15                                                NaN  18.965763  72.819282
# 16                                      B G Kher Road  18.949898  72.801318
# 17                                        Bhakti Park  19.029101  72.877627
# 18          Cooperage Rd, Colaba, Mumbai, Maharashtra  18.918844  72.825933
# 19             Cadell Road, Opposite Catering College  19.023244  72.835148
# 20                                                NaN  18.972489  72.839654
# 21                                             Colaba  18.918839  72.828051
# 22                                                NaN  18.973326  72.823997
# 23                                       Malabar Hill  18.951897  72.799129
# 24                                                NaN  18.916561  72.816366
# 25                                                NaN  18.972708  72.842735
# 26                      Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 27                                            Byculla  18.984533  72.835280
# 28                                                NaN  18.967493  72.803746
# 29                                                NaN  18.995185  72.824560
#
#    postalCode           state
# 0      400006     Mahārāshtra
# 1      400013     Mahārāshtra
# 2      400026     Mahārāshtra
# 3       46123         Indiana
# 4      400066     Mahārāshtra
# 5         NaN     Mahārāshtra
# 6      400001     Mahārāshtra
# 7      400003     Mahārāshtra
# 8      400012     Mahārāshtra
# 9         NaN             NaN
# 10     400037     Mahārāshtra
# 11        NaN     Mahārāshtra
# 12        NaN     Mahārāshtra
# 13        NaN             NaN
# 14        NaN  Madhya Pradesh
# 15        NaN             NaN
# 16    400 026     Mahārāshtra
# 17        NaN     Mahārāshtra
# 18        NaN     Mahārāshtra
# 19        NaN     Mahārāshtra
# 20        NaN             NaN
# 21     400005     Mahārāshtra
# 22        NaN             NaN
# 23     400006     Mahārāshtra
# 24        NaN             NaN
# 25        NaN             NaN
# 26    400 028     Mahārāshtra
# 27        NaN     Mahārāshtra
# 28        NaN             NaN
# 29        NaN             NaN

# %%
clean_park_dataframe2['categories'] =clean_park_dataframe2['categories'].replace('Playground','Park')
clean_park_dataframe2
# Out:
#                                name                                categories  \
# 0                Priyadarshini Park                                      Park
# 1          Peninsula Corporate Park                                  Building
# 2   Harish Mahindra Children's Park                                      Park
# 3         Traditions at Reagan Park                                Conference
# 4                       Rivali Park                        Real Estate Office
# 5                       Park Avenue                            Clothing Store
# 6                       Park Avenue                               Men's Store
# 7              Hotel Residency Park                                     Hotel
# 8                  One Avighna Park                       Housing Development
# 9              Hotel Residency Park                                     Hotel
# 10                      Bhakti Park                       Housing Development
# 11                     Badhwar Park                       Housing Development
# 12          Peninsula Business Park                           Coworking Space
# 13                     Badhwar Park                              Neighborhood
# 14              Kanha National Park                      Other Great Outdoors
# 15                     Park Shilton                                Restaurant
# 16                Kamala Nehru Park                       Monument / Landmark
# 17     Bhakti Park Monorail Station                        Light Rail Station
# 18                     Traffic Park                                      Park
# 19      China Garden Shivaji Park ¤                        Chinese Restaurant
# 20                      saifee park  Residential Building (Apartment / Condo)
# 21                     Badhwar Park  Residential Building (Apartment / Condo)
# 22                        Park View  Residential Building (Apartment / Condo)
# 23                        Hill Park  Residential Building (Apartment / Condo)
# 24                  Land's End Park                                      Park
# 25              Saifee Burhani Park  Residential Building (Apartment / Condo)
# 26                     Shivaji Park                                      Park
# 27                      Nirmal Park                     Outdoors & Recreation
# 28             Harish Mahindra Park                                      Park
# 29                Park Avenue Women                             Women's Store
#
#                                               address        lat        lng  \
# 0                                     Nepean Sea Road  18.957515  72.799614
# 1                                         Lower Parel  18.998626  72.825408
# 2            Breach Candy, Behind American Counsulate  18.914867  72.823688
# 3                                 1176 Kingwood Drive  18.949804  72.834699
# 4   Rivali Park, Western Express Highway,Borivali ...  18.929599  72.828181
# 5                             in High Street Phoenix,  18.996986  72.826677
# 6   Shop No. 32/34, Churchgate House, Veer Nariman...  18.920214  72.830151
# 7                                                 NaN  18.953120  72.835175
# 8                           Mahadev Palav Marg, Parel  18.994041  72.834806
# 9                                                 NaN  18.953255  72.835320
# 10                                   Near Imax Adlabs  19.027670  72.880010
# 11                                     Wodehouse Road  18.919160  72.826648
# 12                              Karamveer Yadav Chowk  18.998868  72.828123
# 13                                                NaN  18.921100  72.827300
# 14                                                NaN  18.923037  72.822986
# 15                                                NaN  18.965763  72.819282
# 16                                      B G Kher Road  18.949898  72.801318
# 17                                        Bhakti Park  19.029101  72.877627
# 18          Cooperage Rd, Colaba, Mumbai, Maharashtra  18.918844  72.825933
# 19             Cadell Road, Opposite Catering College  19.023244  72.835148
# 20                                                NaN  18.972489  72.839654
# 21                                             Colaba  18.918839  72.828051
# 22                                                NaN  18.973326  72.823997
# 23                                       Malabar Hill  18.951897  72.799129
# 24                                                NaN  18.916561  72.816366
# 25                                                NaN  18.972708  72.842735
# 26                      Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 27                                            Byculla  18.984533  72.835280
# 28                                                NaN  18.967493  72.803746
# 29                                                NaN  18.995185  72.824560
#
#    postalCode           state
# 0      400006     Mahārāshtra
# 1      400013     Mahārāshtra
# 2      400026     Mahārāshtra
# 3       46123         Indiana
# 4      400066     Mahārāshtra
# 5         NaN     Mahārāshtra
# 6      400001     Mahārāshtra
# 7      400003     Mahārāshtra
# 8      400012     Mahārāshtra
# 9         NaN             NaN
# 10     400037     Mahārāshtra
# 11        NaN     Mahārāshtra
# 12        NaN     Mahārāshtra
# 13        NaN             NaN
# 14        NaN  Madhya Pradesh
# 15        NaN             NaN
# 16    400 026     Mahārāshtra
# 17        NaN     Mahārāshtra
# 18        NaN     Mahārāshtra
# 19        NaN     Mahārāshtra
# 20        NaN             NaN
# 21     400005     Mahārāshtra
# 22        NaN             NaN
# 23     400006     Mahārāshtra
# 24        NaN             NaN
# 25        NaN             NaN
# 26    400 028     Mahārāshtra
# 27        NaN     Mahārāshtra
# 28        NaN             NaN
# 29        NaN             NaN

# %%
 
clean_park_dataframe2= clean_park_dataframe2[clean_park_dataframe2['categories'].str.contains("Park")]

# %%
p_df=clean_park_dataframe2

# %%
p_df['postalCode'] = p_df['postalCode'].replace(np.nan, 400101)
p_df['state'] = p_df['state'].replace('Mahārāshtra','Maharashtra')
p_df['state'] = p_df['state'].replace(np.nan,'Maharashtra')
p_df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                name categories  \
# 0                Priyadarshini Park       Park
# 2   Harish Mahindra Children's Park       Park
# 18                     Traffic Park       Park
# 24                  Land's End Park       Park
# 26                     Shivaji Park       Park
# 28             Harish Mahindra Park       Park
#
#                                       address        lat        lng  \
# 0                             Nepean Sea Road  18.957515  72.799614
# 2    Breach Candy, Behind American Counsulate  18.914867  72.823688
# 18  Cooperage Rd, Colaba, Mumbai, Maharashtra  18.918844  72.825933
# 24                                        NaN  18.916561  72.816366
# 26              Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 28                                        NaN  18.967493  72.803746
#
#    postalCode        state
# 0      400006  Maharashtra
# 2      400026  Maharashtra
# 18     400101  Maharashtra
# 24     400101  Maharashtra
# 26    400 028  Maharashtra
# 28     400101  Maharashtra

# %%
p_df
# Out:
#                                name categories  \
# 0                Priyadarshini Park       Park
# 2   Harish Mahindra Children's Park       Park
# 18                     Traffic Park       Park
# 24                  Land's End Park       Park
# 26                     Shivaji Park       Park
# 28             Harish Mahindra Park       Park
#
#                                       address        lat        lng  \
# 0                             Nepean Sea Road  18.957515  72.799614
# 2    Breach Candy, Behind American Counsulate  18.914867  72.823688
# 18  Cooperage Rd, Colaba, Mumbai, Maharashtra  18.918844  72.825933
# 24                                        NaN  18.916561  72.816366
# 26              Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 28                                        NaN  18.967493  72.803746
#
#    postalCode        state
# 0      400006  Maharashtra
# 2      400026  Maharashtra
# 18     400101  Maharashtra
# 24     400101  Maharashtra
# 26    400 028  Maharashtra
# 28     400101  Maharashtra

# %%
df_park=p_df

# %%
df_park
# Out:
#                                name categories  \
# 0                Priyadarshini Park       Park
# 2   Harish Mahindra Children's Park       Park
# 18                     Traffic Park       Park
# 24                  Land's End Park       Park
# 26                     Shivaji Park       Park
# 28             Harish Mahindra Park       Park
#
#                                       address        lat        lng  \
# 0                             Nepean Sea Road  18.957515  72.799614
# 2    Breach Candy, Behind American Counsulate  18.914867  72.823688
# 18  Cooperage Rd, Colaba, Mumbai, Maharashtra  18.918844  72.825933
# 24                                        NaN  18.916561  72.816366
# 26              Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 28                                        NaN  18.967493  72.803746
#
#    postalCode        state
# 0      400006  Maharashtra
# 2      400026  Maharashtra
# 18     400101  Maharashtra
# 24     400101  Maharashtra
# 26    400 028  Maharashtra
# 28     400101  Maharashtra

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AACVJZ5QQJBAAIRAQ1F41HBULHIMT1JVS4PDWD2TD1VGJIKV&client_secret=5201AOLYTAS41XZPRYJM4XB0EAXKEEAXUGY2GETOTF2L3UDJ&ll=18.9387711,72.8353355&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                          id                               name  \
# 0  4e4c0a4122713bd908c641ff                 Farhang Restaurant
# 1  5263f0f5498edc1ad5f3270f  Nanumal Bhojraj Restaurant - Fort
# 2  4c09449eed2595217aee1256        Stadium Restaurant & Stores
# 3  4e7c3bdf52b10564f7f6fd20               Sai Pooja Restaurant
# 4  4fb5276be4b0b34b9ac27a1b               Iran Like Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1564039045    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1564039045    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1564039045    False
# 3                                                 []  v-1564039045    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1564039045    False
#
#               location.address                location.crossStreet  \
# 0                 Opposite GPO                      Ballard Estate
# 1           Near GPO, Fort, VT                S. Bhagat Singh Road
# 2            Veer Nariman Road  Next to Vodafone Store, Churchgate
# 3                          NaN                                 NaN
# 4  Palton Road, Near Haj House                                 NaN
#
#    location.lat  location.lng  \
# 0     18.938165     72.837917
# 1     18.937974     72.837663
# 2     18.933173     72.826929
# 3     18.938357     72.835073
# 4     18.945343     72.836809
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.93816453050136...                280
# 1  [{'label': 'display', 'lat': 18.93797448587734...                260
# 2  [{'label': 'display', 'lat': 18.93317339191467...               1082
# 3  [{'label': 'display', 'lat': 18.93835719323860...                 53
# 4  [{'label': 'display', 'lat': 18.94534293649397...                747
#
#   location.cc location.city location.state location.country  \
# 0          IN        Mumbai    Mahārāshtra            India
# 1          IN        Mumbai    Mahārāshtra            India
# 2          IN        Mumbai    Mahārāshtra            India
# 3          IN        Mumbai    Mahārāshtra            India
# 4          IN        Mumbai    Mahārāshtra            India
#
#                            location.formattedAddress location.postalCode
# 0  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...                 NaN
# 1  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...              400001
# 2  [Veer Nariman Road (Next to Vodafone Store, Ch...              400023
# 3                       [Mumbai, Mahārāshtra, India]                 NaN
# 4  [Palton Road, Near Haj House, Mumbai 400001, M...              400001

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                 name         categories  \
# 0                 Farhang Restaurant         Steakhouse
# 1  Nanumal Bhojraj Restaurant - Fort  Indian Restaurant
# 2        Stadium Restaurant & Stores  Indian Restaurant
# 3               Sai Pooja Restaurant               None
# 4               Iran Like Restaurant  Indian Restaurant
#
#                        address                         crossStreet        lat  \
# 0                 Opposite GPO                      Ballard Estate  18.938165
# 1           Near GPO, Fort, VT                S. Bhagat Singh Road  18.937974
# 2            Veer Nariman Road  Next to Vodafone Store, Churchgate  18.933173
# 3                          NaN                                 NaN  18.938357
# 4  Palton Road, Near Haj House                                 NaN  18.945343
#
#          lng                                     labeledLatLngs  distance  cc  \
# 0  72.837917  [{'label': 'display', 'lat': 18.93816453050136...       280  IN
# 1  72.837663  [{'label': 'display', 'lat': 18.93797448587734...       260  IN
# 2  72.826929  [{'label': 'display', 'lat': 18.93317339191467...      1082  IN
# 3  72.835073  [{'label': 'display', 'lat': 18.93835719323860...        53  IN
# 4  72.836809  [{'label': 'display', 'lat': 18.94534293649397...       747  IN
#
#      city        state country  \
# 0  Mumbai  Mahārāshtra   India
# 1  Mumbai  Mahārāshtra   India
# 2  Mumbai  Mahārāshtra   India
# 3  Mumbai  Mahārāshtra   India
# 4  Mumbai  Mahārāshtra   India
#
#                                     formattedAddress postalCode  \
# 0  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...        NaN
# 1  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...     400001
# 2  [Veer Nariman Road (Next to Vodafone Store, Ch...     400023
# 3                       [Mumbai, Mahārāshtra, India]        NaN
# 4  [Palton Road, Near Haj House, Mumbai 400001, M...     400001
#
#                          id
# 0  4e4c0a4122713bd908c641ff
# 1  5263f0f5498edc1ad5f3270f
# 2  4c09449eed2595217aee1256
# 3  4e7c3bdf52b10564f7f6fd20
# 4  4fb5276be4b0b34b9ac27a1b

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
df=clean_Restaurant_dataframe2

# %%
df
# Out:
#                                           name            categories  \
# 0                           Farhang Restaurant            Steakhouse
# 1            Nanumal Bhojraj Restaurant - Fort     Indian Restaurant
# 2                  Stadium Restaurant & Stores     Indian Restaurant
# 3                         Sai Pooja Restaurant                  None
# 4                         Iran Like Restaurant     Indian Restaurant
# 5                      New Majestic Restaurant     Indian Restaurant
# 6                  Panchratna restaurant & bar     Indian Restaurant
# 7                              Aram Restaurant      Asian Restaurant
# 8                            Poonam Restaurant            Restaurant
# 9                            Canara Restaurant     Indian Restaurant
# 10  Nanumal Bhojraj Restaurant - Masjid Bunder     Indian Restaurant
# 11                          Kalpana restaurant                  None
# 12                         National Restaurant                  Food
# 13                          Kamat's Restaurant     Indian Restaurant
# 14                Fountain Sizzlers Restaurant     Indian Restaurant
# 15                     Golden Wheel Restaurant            Restaurant
# 16                          Gulshan Restaurant     Indian Restaurant
# 17                   Mangalore naaz Restaurant      Asian Restaurant
# 18                Sind Punjab Bar & Restaurant            Restaurant
# 19                           Bombay Restaurant     Indian Restaurant
# 20                    Anubhav Restaurant & Bar     Indian Restaurant
# 21                            Lalit restaurant                   Bar
# 22                        New Udupi Restaurant  Fast Food Restaurant
# 23                         Goodluck Restaurant                  None
# 24                       queen mary restaurant                  Café
# 25                      Excellensea Restaurant             BBQ Joint
# 26                           Kayani Restaurant            Irani Cafe
# 27                      Royal China Restaurant  Cantonese Restaurant
# 28                         Brighton Restaurant            Restaurant
# 29                          Ustaadi Restaurant                Lounge
#
#                                               address        lat        lng  \
# 0                                        Opposite GPO  18.938165  72.837917
# 1                                  Near GPO, Fort, VT  18.937974  72.837663
# 2                                   Veer Nariman Road  18.933173  72.826929
# 3                                                 NaN  18.938357  72.835073
# 4                         Palton Road, Near Haj House  18.945343  72.836809
# 5                                             Opp CST  18.938972  72.835517
# 6                                   Opp. Metro Cinema  18.942900  72.826820
# 7                           Capitol building, DN Road  18.939543  72.834495
# 8                                                 NaN  18.939225  72.835707
# 9                                                 NaN  18.936847  72.837525
# 10  Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 11                                                Gpo  18.937489  72.836157
# 12                                    opp fort market  18.935112  72.836896
# 13                        Opp. Electric House, Colaba  18.921570  72.831004
# 14                             57 Mahatma Gandhi Road  18.931366  72.831462
# 15                                            Girgaon  18.954636  72.819690
# 16                                                NaN  18.938199  72.837764
# 17                                                NaN  18.937245  72.837606
# 18                        263, SBS Road, Fort, Mumbai  18.937048  72.837381
# 19                                                NaN  18.935902  72.834426
# 20                                                NaN  18.936497  72.837586
# 21                                 Cawasji Patel road  18.935002  72.833791
# 22                                                NaN  18.933005  72.834305
# 23                                                NaN  18.935578  72.837357
# 24                                                NaN  18.969932  72.835495
# 25                                          Mint Road  18.935266  72.837240
# 26                                                NaN  18.935040  72.836941
# 27                                                NaN  18.937876  72.831005
# 28                                                NaN  18.935007  72.833687
# 29                          B Block, Sitaram Building  18.945482  72.834270
#
#           state postalCode
# 0   Mahārāshtra        NaN
# 1   Mahārāshtra     400001
# 2   Mahārāshtra     400023
# 3   Mahārāshtra        NaN
# 4   Mahārāshtra     400001
# 5   Mahārāshtra        NaN
# 6   Mahārāshtra        NaN
# 7   Mahārāshtra        NaN
# 8           NaN        NaN
# 9           NaN        NaN
# 10  Mahārāshtra     400009
# 11  Mahārāshtra        NaN
# 12  Mahārāshtra     400001
# 13  Mahārāshtra        NaN
# 14  Mahārāshtra    400 023
# 15  Mahārāshtra        NaN
# 16  Mahārāshtra     400001
# 17          NaN        NaN
# 18          NaN        NaN
# 19  Mahārāshtra        NaN
# 20  Mahārāshtra     400001
# 21  Mahārāshtra     400001
# 22  Mahārāshtra     400001
# 23  Mahārāshtra        NaN
# 24          NaN        NaN
# 25  Mahārāshtra     400001
# 26          NaN        NaN
# 27          NaN        NaN
# 28          NaN        NaN
# 29  Mahārāshtra     400001

# %%
df['postalCode'] = df['postalCode'].replace(np.nan, 400101)
df['state'] =df['state'].replace('Mahārāshtra','Maharashtra')
df['address'] =df['address'].replace(np.nan,'South Mumbai')
df['state'] =df['state'].replace(np.nan,'Maharashtra')
df
# Out:
#                                           name            categories  \
# 0                           Farhang Restaurant            Steakhouse
# 1            Nanumal Bhojraj Restaurant - Fort     Indian Restaurant
# 2                  Stadium Restaurant & Stores     Indian Restaurant
# 3                         Sai Pooja Restaurant                  None
# 4                         Iran Like Restaurant     Indian Restaurant
# 5                      New Majestic Restaurant     Indian Restaurant
# 6                  Panchratna restaurant & bar     Indian Restaurant
# 7                              Aram Restaurant      Asian Restaurant
# 8                            Poonam Restaurant            Restaurant
# 9                            Canara Restaurant     Indian Restaurant
# 10  Nanumal Bhojraj Restaurant - Masjid Bunder     Indian Restaurant
# 11                          Kalpana restaurant                  None
# 12                         National Restaurant                  Food
# 13                          Kamat's Restaurant     Indian Restaurant
# 14                Fountain Sizzlers Restaurant     Indian Restaurant
# 15                     Golden Wheel Restaurant            Restaurant
# 16                          Gulshan Restaurant     Indian Restaurant
# 17                   Mangalore naaz Restaurant      Asian Restaurant
# 18                Sind Punjab Bar & Restaurant            Restaurant
# 19                           Bombay Restaurant     Indian Restaurant
# 20                    Anubhav Restaurant & Bar     Indian Restaurant
# 21                            Lalit restaurant                   Bar
# 22                        New Udupi Restaurant  Fast Food Restaurant
# 23                         Goodluck Restaurant                  None
# 24                       queen mary restaurant                  Café
# 25                      Excellensea Restaurant             BBQ Joint
# 26                           Kayani Restaurant            Irani Cafe
# 27                      Royal China Restaurant  Cantonese Restaurant
# 28                         Brighton Restaurant            Restaurant
# 29                          Ustaadi Restaurant                Lounge
#
#                                               address        lat        lng  \
# 0                                        Opposite GPO  18.938165  72.837917
# 1                                  Near GPO, Fort, VT  18.937974  72.837663
# 2                                   Veer Nariman Road  18.933173  72.826929
# 3                                        South Mumbai  18.938357  72.835073
# 4                         Palton Road, Near Haj House  18.945343  72.836809
# 5                                             Opp CST  18.938972  72.835517
# 6                                   Opp. Metro Cinema  18.942900  72.826820
# 7                           Capitol building, DN Road  18.939543  72.834495
# 8                                        South Mumbai  18.939225  72.835707
# 9                                        South Mumbai  18.936847  72.837525
# 10  Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 11                                                Gpo  18.937489  72.836157
# 12                                    opp fort market  18.935112  72.836896
# 13                        Opp. Electric House, Colaba  18.921570  72.831004
# 14                             57 Mahatma Gandhi Road  18.931366  72.831462
# 15                                            Girgaon  18.954636  72.819690
# 16                                       South Mumbai  18.938199  72.837764
# 17                                       South Mumbai  18.937245  72.837606
# 18                        263, SBS Road, Fort, Mumbai  18.937048  72.837381
# 19                                       South Mumbai  18.935902  72.834426
# 20                                       South Mumbai  18.936497  72.837586
# 21                                 Cawasji Patel road  18.935002  72.833791
# 22                                       South Mumbai  18.933005  72.834305
# 23                                       South Mumbai  18.935578  72.837357
# 24                                       South Mumbai  18.969932  72.835495
# 25                                          Mint Road  18.935266  72.837240
# 26                                       South Mumbai  18.935040  72.836941
# 27                                       South Mumbai  18.937876  72.831005
# 28                                       South Mumbai  18.935007  72.833687
# 29                          B Block, Sitaram Building  18.945482  72.834270
#
#           state postalCode
# 0   Maharashtra     400101
# 1   Maharashtra     400001
# 2   Maharashtra     400023
# 3   Maharashtra     400101
# 4   Maharashtra     400001
# 5   Maharashtra     400101
# 6   Maharashtra     400101
# 7   Maharashtra     400101
# 8   Maharashtra     400101
# 9   Maharashtra     400101
# 10  Maharashtra     400009
# 11  Maharashtra     400101
# 12  Maharashtra     400001
# 13  Maharashtra     400101
# 14  Maharashtra    400 023
# 15  Maharashtra     400101
# 16  Maharashtra     400001
# 17  Maharashtra     400101
# 18  Maharashtra     400101
# 19  Maharashtra     400101
# 20  Maharashtra     400001
# 21  Maharashtra     400001
# 22  Maharashtra     400001
# 23  Maharashtra     400101
# 24  Maharashtra     400101
# 25  Maharashtra     400001
# 26  Maharashtra     400101
# 27  Maharashtra     400101
# 28  Maharashtra     400101
# 29  Maharashtra     400001

# %%
df_restaurant=df
df_restaurant
# Out:
#                                           name            categories  \
# 0                           Farhang Restaurant            Steakhouse
# 1            Nanumal Bhojraj Restaurant - Fort     Indian Restaurant
# 2                  Stadium Restaurant & Stores     Indian Restaurant
# 3                         Sai Pooja Restaurant                  None
# 4                         Iran Like Restaurant     Indian Restaurant
# 5                      New Majestic Restaurant     Indian Restaurant
# 6                  Panchratna restaurant & bar     Indian Restaurant
# 7                              Aram Restaurant      Asian Restaurant
# 8                            Poonam Restaurant            Restaurant
# 9                            Canara Restaurant     Indian Restaurant
# 10  Nanumal Bhojraj Restaurant - Masjid Bunder     Indian Restaurant
# 11                          Kalpana restaurant                  None
# 12                         National Restaurant                  Food
# 13                          Kamat's Restaurant     Indian Restaurant
# 14                Fountain Sizzlers Restaurant     Indian Restaurant
# 15                     Golden Wheel Restaurant            Restaurant
# 16                          Gulshan Restaurant     Indian Restaurant
# 17                   Mangalore naaz Restaurant      Asian Restaurant
# 18                Sind Punjab Bar & Restaurant            Restaurant
# 19                           Bombay Restaurant     Indian Restaurant
# 20                    Anubhav Restaurant & Bar     Indian Restaurant
# 21                            Lalit restaurant                   Bar
# 22                        New Udupi Restaurant  Fast Food Restaurant
# 23                         Goodluck Restaurant                  None
# 24                       queen mary restaurant                  Café
# 25                      Excellensea Restaurant             BBQ Joint
# 26                           Kayani Restaurant            Irani Cafe
# 27                      Royal China Restaurant  Cantonese Restaurant
# 28                         Brighton Restaurant            Restaurant
# 29                          Ustaadi Restaurant                Lounge
#
#                                               address        lat        lng  \
# 0                                        Opposite GPO  18.938165  72.837917
# 1                                  Near GPO, Fort, VT  18.937974  72.837663
# 2                                   Veer Nariman Road  18.933173  72.826929
# 3                                        South Mumbai  18.938357  72.835073
# 4                         Palton Road, Near Haj House  18.945343  72.836809
# 5                                             Opp CST  18.938972  72.835517
# 6                                   Opp. Metro Cinema  18.942900  72.826820
# 7                           Capitol building, DN Road  18.939543  72.834495
# 8                                        South Mumbai  18.939225  72.835707
# 9                                        South Mumbai  18.936847  72.837525
# 10  Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 11                                                Gpo  18.937489  72.836157
# 12                                    opp fort market  18.935112  72.836896
# 13                        Opp. Electric House, Colaba  18.921570  72.831004
# 14                             57 Mahatma Gandhi Road  18.931366  72.831462
# 15                                            Girgaon  18.954636  72.819690
# 16                                       South Mumbai  18.938199  72.837764
# 17                                       South Mumbai  18.937245  72.837606
# 18                        263, SBS Road, Fort, Mumbai  18.937048  72.837381
# 19                                       South Mumbai  18.935902  72.834426
# 20                                       South Mumbai  18.936497  72.837586
# 21                                 Cawasji Patel road  18.935002  72.833791
# 22                                       South Mumbai  18.933005  72.834305
# 23                                       South Mumbai  18.935578  72.837357
# 24                                       South Mumbai  18.969932  72.835495
# 25                                          Mint Road  18.935266  72.837240
# 26                                       South Mumbai  18.935040  72.836941
# 27                                       South Mumbai  18.937876  72.831005
# 28                                       South Mumbai  18.935007  72.833687
# 29                          B Block, Sitaram Building  18.945482  72.834270
#
#           state postalCode
# 0   Maharashtra     400101
# 1   Maharashtra     400001
# 2   Maharashtra     400023
# 3   Maharashtra     400101
# 4   Maharashtra     400001
# 5   Maharashtra     400101
# 6   Maharashtra     400101
# 7   Maharashtra     400101
# 8   Maharashtra     400101
# 9   Maharashtra     400101
# 10  Maharashtra     400009
# 11  Maharashtra     400101
# 12  Maharashtra     400001
# 13  Maharashtra     400101
# 14  Maharashtra    400 023
# 15  Maharashtra     400101
# 16  Maharashtra     400001
# 17  Maharashtra     400101
# 18  Maharashtra     400101
# 19  Maharashtra     400101
# 20  Maharashtra     400001
# 21  Maharashtra     400001
# 22  Maharashtra     400001
# 23  Maharashtra     400101
# 24  Maharashtra     400101
# 25  Maharashtra     400001
# 26  Maharashtra     400101
# 27  Maharashtra     400101
# 28  Maharashtra     400101
# 29  Maharashtra     400001

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AACVJZ5QQJBAAIRAQ1F41HBULHIMT1JVS4PDWD2TD1VGJIKV&client_secret=5201AOLYTAS41XZPRYJM4XB0EAXKEEAXUGY2GETOTF2L3UDJ&ll=18.9387711,72.8353355&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                          id                         name  \
# 0  4e81776030f86985e40abb54                    Cafeteria
# 1  50050da9e4b0d73a8dfa7ee9    Cafeteria at Tata Capital
# 2  4e2943f02271752a459cb122  Mumbai High Court Cafeteria
# 3  4bdfcc5affdec9286e31eda1   Cafeteria at Indian Hotels
# 4  4d53497cd4a6721ec05589ac                    Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1564039610    False
# 1  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1564039610    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1564039610    False
# 3                                                 []  v-1564039610    False
# 4                                                 []  v-1564039610    False
#
#          location.address  location.lat  location.lng  \
# 0   Breach Candy Hospital     18.971833     72.804981
# 1              One Forbes     18.930769     72.835434
# 2                    Fort     18.933198     72.829170
# 3           Oxford Towers     18.922937     72.832849
# 4  Mumbai central station     18.970839     72.820636
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.97183316652913...               4874
# 1  [{'label': 'display', 'lat': 18.930769, 'lng':...                890
# 2  [{'label': 'display', 'lat': 18.93319755884302...                898
# 3  [{'label': 'display', 'lat': 18.922937, 'lng':...               1781
# 4  [{'label': 'display', 'lat': 18.97083858982881...               3890
#
#   location.postalCode location.cc location.city location.state  \
# 0              400026          IN        Mumbai    Mahārāshtra
# 1                 NaN          IN        Mumbai    Mahārāshtra
# 2                 NaN          IN        Mumbai    Mahārāshtra
# 3                 NaN          IN           NaN    Mahārāshtra
# 4                 NaN          IN        Mumbai    Mahārāshtra
#
#   location.country                          location.formattedAddress  \
# 0            India  [Breach Candy Hospital, Mumbai 400026, Mahārās...
# 1            India  [One Forbes (Kala Ghoda), Mumbai, Mahārāshtra,...
# 2            India                 [Fort, Mumbai, Mahārāshtra, India]
# 3            India                [Oxford Towers, Mahārāshtra, India]
# 4            India  [Mumbai central station, Mumbai, Mahārāshtra, ...
#
#   location.crossStreet
# 0                  NaN
# 1           Kala Ghoda
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                           name  categories                 address        lat  \
# 0                    Cafeteria        Café   Breach Candy Hospital  18.971833
# 1    Cafeteria at Tata Capital  Food Court              One Forbes  18.930769
# 2  Mumbai High Court Cafeteria  Food Court                    Fort  18.933198
# 3   Cafeteria at Indian Hotels        None           Oxford Towers  18.922937
# 4                    Cafeteria        None  Mumbai central station  18.970839
#
#          lng                                     labeledLatLngs  distance  \
# 0  72.804981  [{'label': 'display', 'lat': 18.97183316652913...      4874
# 1  72.835434  [{'label': 'display', 'lat': 18.930769, 'lng':...       890
# 2  72.829170  [{'label': 'display', 'lat': 18.93319755884302...       898
# 3  72.832849  [{'label': 'display', 'lat': 18.922937, 'lng':...      1781
# 4  72.820636  [{'label': 'display', 'lat': 18.97083858982881...      3890
#
#   postalCode  cc    city        state country  \
# 0     400026  IN  Mumbai  Mahārāshtra   India
# 1        NaN  IN  Mumbai  Mahārāshtra   India
# 2        NaN  IN  Mumbai  Mahārāshtra   India
# 3        NaN  IN     NaN  Mahārāshtra   India
# 4        NaN  IN  Mumbai  Mahārāshtra   India
#
#                                     formattedAddress crossStreet  \
# 0  [Breach Candy Hospital, Mumbai 400026, Mahārās...         NaN
# 1  [One Forbes (Kala Ghoda), Mumbai, Mahārāshtra,...  Kala Ghoda
# 2                 [Fort, Mumbai, Mahārāshtra, India]         NaN
# 3                [Oxford Towers, Mahārāshtra, India]         NaN
# 4  [Mumbai central station, Mumbai, Mahārāshtra, ...         NaN
#
#                          id
# 0  4e81776030f86985e40abb54
# 1  50050da9e4b0d73a8dfa7ee9
# 2  4e2943f02271752a459cb122
# 3  4bdfcc5affdec9286e31eda1
# 4  4d53497cd4a6721ec05589ac

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                         name                 categories  \
# 0                                  Cafeteria                       Café
# 1                  Cafeteria at Tata Capital                 Food Court
# 2                Mumbai High Court Cafeteria                 Food Court
# 3                 Cafeteria at Indian Hotels                       None
# 4                                  Cafeteria                       None
# 5   KES College of Commerce & Arts Cafeteria          College Cafeteria
# 6                    Cafeteria - P2 Building                  Cafeteria
# 7                   Cafeteria, Lodha Excelus                  Cafeteria
# 8                           Jai Hind College  College Academic Building
# 9                  Burhani College Cafeteria          College Cafeteria
# 10                       Jan Ahaar Cafeteria                      Diner
# 11                             G2W Cafeteria                  Cafeteria
# 12                           Essar Cafeteria                       Food
# 13                     Leo Burnett Cafeteria                  Cafeteria
# 14        Empire Cafeteria (Siddhi caterers)                       Café
# 15               Mahindra Holidays Cafeteria                Snack Place
# 16                           burhani college      College Arts Building
# 17                    Ashok Towers Cafeteria                       Café
# 18                    Adfactors PR Cafeteria                     Buffet
# 19                 Mahindra Towers Cafeteria                  Cafeteria
# 20                         Leo Burnett India                     Office
# 21                         Indigo Consulting                   Building
# 22                              BloombergUTV                 Food Court
# 23                   VIT Executive Cafeteria          College Cafeteria
# 24                             Bloomberg UTV                 Food Court
# 25                       welingkar cafeteria                  Cafeteria
# 26        Price Waterhouse Coopers cafeteria                       Café
# 27                                Network 18                     Office
#
#                                               address        lat        lng  \
# 0                               Breach Candy Hospital  18.971833  72.804981
# 1                                          One Forbes  18.930769  72.835434
# 2                                                Fort  18.933198  72.829170
# 3                                       Oxford Towers  18.922937  72.832849
# 4                              Mumbai central station  18.970839  72.820636
# 5                                         Parekh lane  18.948587  72.829424
# 6                            Next to Phoenix Building  18.992866  72.823965
# 7                           9th Floor, Lodha Excelus,  18.994027  72.834380
# 8                                  A Road, Churchgate  18.934689  72.824822
# 9                           Opp St Mary's School ICSE  18.964665  72.843831
# 10                             Mumbai Central Station  18.975868  72.823434
# 11                                                NaN  18.974342  72.813182
# 12                                                NaN  18.979570  72.819515
# 13                                     36-A Big Apple  18.998785  72.840376
# 14               Empire Mills Compound, Tulsi Pipe Rd  19.000831  72.828339
# 15  Mahindra Holidays, Mahindra Towers, G.M. Bhosl...  19.005692  72.822309
# 16                                           Mazagoan  18.970446  72.835390
# 17                                       Ashok Towers  18.997597  72.837888
# 18                                                NaN  19.005008  72.826450
# 19                                              Worli  19.006044  72.820630
# 20                                                NaN  18.998824  72.840360
# 21                                      The Big Apple  18.998891  72.840350
# 22            Parijaat House, 1076, Dr. E Moses Road,  18.996397  72.819472
# 23                Vidyalankar Institute Of Technology  19.021675  72.870364
# 24                                                NaN  18.996877  72.819759
# 25                                                NaN  19.025060  72.850341
# 26                                                NaN  19.030498  72.838367
# 27                New Empire Complex, Lower Parel (w)  19.031835  72.845926
#
#    postalCode        state
# 0      400026  Mahārāshtra
# 1         NaN  Mahārāshtra
# 2         NaN  Mahārāshtra
# 3         NaN  Mahārāshtra
# 4         NaN  Mahārāshtra
# 5      400067  Mahārāshtra
# 6      400013  Mahārāshtra
# 7      400011  Mahārāshtra
# 8     400 020  Mahārāshtra
# 9         NaN  Mahārāshtra
# 10        NaN          NaN
# 11        NaN          NaN
# 12        NaN  Mahārāshtra
# 13     400012  Mahārāshtra
# 14        NaN  Mahārāshtra
# 15     400018  Mahārāshtra
# 16     400010  Mahārāshtra
# 17        NaN  Mahārāshtra
# 18        NaN          NaN
# 19     400030  Mahārāshtra
# 20        NaN          NaN
# 21     400012  Mahārāshtra
# 22     400018  Mahārāshtra
# 23     400037  Mahārāshtra
# 24        NaN          NaN
# 25        NaN          NaN
# 26        NaN          NaN
# 27        NaN  Mahārāshtra

# %%
clean_Cafeteria_dataframe2['categories'] =clean_Cafeteria_dataframe2['categories'].replace('Café','Cafeteria')
df_cafeteria = clean_Cafeteria_dataframe2[clean_Cafeteria_dataframe2.categories == 'Cafeteria'] 
df_cafeteria
# Out:
#                                   name categories  \
# 0                            Cafeteria  Cafeteria
# 6              Cafeteria - P2 Building  Cafeteria
# 7             Cafeteria, Lodha Excelus  Cafeteria
# 11                       G2W Cafeteria  Cafeteria
# 13               Leo Burnett Cafeteria  Cafeteria
# 14  Empire Cafeteria (Siddhi caterers)  Cafeteria
# 17              Ashok Towers Cafeteria  Cafeteria
# 19           Mahindra Towers Cafeteria  Cafeteria
# 25                 welingkar cafeteria  Cafeteria
# 26  Price Waterhouse Coopers cafeteria  Cafeteria
#
#                                  address        lat        lng postalCode  \
# 0                  Breach Candy Hospital  18.971833  72.804981     400026
# 6               Next to Phoenix Building  18.992866  72.823965     400013
# 7              9th Floor, Lodha Excelus,  18.994027  72.834380     400011
# 11                                   NaN  18.974342  72.813182        NaN
# 13                        36-A Big Apple  18.998785  72.840376     400012
# 14  Empire Mills Compound, Tulsi Pipe Rd  19.000831  72.828339        NaN
# 17                          Ashok Towers  18.997597  72.837888        NaN
# 19                                 Worli  19.006044  72.820630     400030
# 25                                   NaN  19.025060  72.850341        NaN
# 26                                   NaN  19.030498  72.838367        NaN
#
#           state
# 0   Mahārāshtra
# 6   Mahārāshtra
# 7   Mahārāshtra
# 11          NaN
# 13  Mahārāshtra
# 14  Mahārāshtra
# 17  Mahārāshtra
# 19  Mahārāshtra
# 25          NaN
# 26          NaN

# %%
# search for Shopping
search_query = 'Cinema'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AACVJZ5QQJBAAIRAQ1F41HBULHIMT1JVS4PDWD2TD1VGJIKV&client_secret=5201AOLYTAS41XZPRYJM4XB0EAXKEEAXUGY2GETOTF2L3UDJ&ll=18.9387711,72.8353355&v=20180604&query=Cinema&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                          id                  name  \
# 0  4b10fe04f964a520417723e3     Metro Big Cinemas
# 1  4bf7ff154a67c928ce8024cf  New Excelsior Cinema
# 2  50ed9c68e4b0ac50037c0867     New Empire Cinema
# 3  4c4a8c51bad7a593acc889aa        Liberty cinema
# 4  4f6979dae4b072f146941ac3   Metro Cinema Signal
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d180941735', 'name': 'M...  v-1564042010    False
# 1  [{'id': '4bf58dd8d48988d17f941735', 'name': 'M...  v-1564042010    False
# 2  [{'id': '4bf58dd8d48988d17e941735', 'name': 'I...  v-1564042010    False
# 3  [{'id': '4bf58dd8d48988d17e941735', 'name': 'I...  v-1564042010    False
# 4  [{'id': '4bf58dd8d48988d1f9931735', 'name': 'R...  v-1564042010    False
#
#                      location.address       location.crossStreet  \
# 0  Anandilal Podar Marg, Marine Lines  Opp Cowasji Jehangir Hall
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                  41/42 Marine Lines                        NaN
# 4                                 NaN                        NaN
#
#    location.lat  location.lng  \
# 0     18.943304     72.828897
# 1     18.937665     72.833533
# 2     18.938708     72.834271
# 3     18.941652     72.827389
# 4     18.944518     72.829701
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.94330414995686...                845
# 1  [{'label': 'display', 'lat': 18.93766538686403...                226
# 2  [{'label': 'display', 'lat': 18.93870751039151...                112
# 3  [{'label': 'display', 'lat': 18.94165232157157...                896
# 4  [{'label': 'display', 'lat': 18.94451772552554...                872
#
#   location.cc location.city location.state location.country  \
# 0          IN        Mumbai    Mahārāshtra            India
# 1          IN        Mumbai    Mahārāshtra            India
# 2          IN           NaN            NaN            India
# 3          IN        Mumbai    Mahārāshtra            India
# 4          IN           NaN            NaN            India
#
#                            location.formattedAddress location.postalCode
# 0  [Anandilal Podar Marg, Marine Lines (Opp Cowas...                 NaN
# 1                       [Mumbai, Mahārāshtra, India]                 NaN
# 2                                            [India]                 NaN
# 3   [41/42 Marine Lines, Mumbai, Mahārāshtra, India]                 NaN
# 4                                            [India]                 NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                    name           categories  \
# 0     Metro Big Cinemas            Multiplex
# 1  New Excelsior Cinema        Movie Theater
# 2     New Empire Cinema  Indie Movie Theater
# 3        Liberty cinema  Indie Movie Theater
# 4   Metro Cinema Signal                 Road
#
#                               address                crossStreet        lat  \
# 0  Anandilal Podar Marg, Marine Lines  Opp Cowasji Jehangir Hall  18.943304
# 1                                 NaN                        NaN  18.937665
# 2                                 NaN                        NaN  18.938708
# 3                  41/42 Marine Lines                        NaN  18.941652
# 4                                 NaN                        NaN  18.944518
#
#          lng                                     labeledLatLngs  distance  cc  \
# 0  72.828897  [{'label': 'display', 'lat': 18.94330414995686...       845  IN
# 1  72.833533  [{'label': 'display', 'lat': 18.93766538686403...       226  IN
# 2  72.834271  [{'label': 'display', 'lat': 18.93870751039151...       112  IN
# 3  72.827389  [{'label': 'display', 'lat': 18.94165232157157...       896  IN
# 4  72.829701  [{'label': 'display', 'lat': 18.94451772552554...       872  IN
#
#      city        state country  \
# 0  Mumbai  Mahārāshtra   India
# 1  Mumbai  Mahārāshtra   India
# 2     NaN          NaN   India
# 3  Mumbai  Mahārāshtra   India
# 4     NaN          NaN   India
#
#                                     formattedAddress postalCode  \
# 0  [Anandilal Podar Marg, Marine Lines (Opp Cowas...        NaN
# 1                       [Mumbai, Mahārāshtra, India]        NaN
# 2                                            [India]        NaN
# 3   [41/42 Marine Lines, Mumbai, Mahārāshtra, India]        NaN
# 4                                            [India]        NaN
#
#                          id
# 0  4b10fe04f964a520417723e3
# 1  4bf7ff154a67c928ce8024cf
# 2  50ed9c68e4b0ac50037c0867
# 3  4c4a8c51bad7a593acc889aa
# 4  4f6979dae4b072f146941ac3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country','distance', 'formattedAddress',\
                                        'labeledLatLngs','id'], axis=1)
dfc=clean_Shopping_dataframe2
dfc
# Out:
#                        name           categories  \
# 0         Metro Big Cinemas            Multiplex
# 1      New Excelsior Cinema        Movie Theater
# 2         New Empire Cinema  Indie Movie Theater
# 3            Liberty cinema  Indie Movie Theater
# 4       Metro Cinema Signal                 Road
# 5             Edward Cinema        Movie Theater
# 6  Monginis, Liberty Cinema         Cupcake Shop
# 7        Metro Inox Cinemas            Multiplex
# 8         metro big cinemas           Auditorium
#
#                               address                crossStreet        lat  \
# 0  Anandilal Podar Marg, Marine Lines  Opp Cowasji Jehangir Hall  18.943304
# 1                                 NaN                        NaN  18.937665
# 2                                 NaN                        NaN  18.938708
# 3                  41/42 Marine Lines                        NaN  18.941652
# 4                                 NaN                        NaN  18.944518
# 5                     Kalabadevi Road                        NaN  18.945142
# 6                Near Bombay Hospital                        NaN  18.944101
# 7                      metro Junction               Marine lines  18.943236
# 8                                 NaN                        NaN  18.943835
#
#          lng        state postalCode
# 0  72.828897  Mahārāshtra        NaN
# 1  72.833533  Mahārāshtra        NaN
# 2  72.834271          NaN        NaN
# 3  72.827389  Mahārāshtra        NaN
# 4  72.829701          NaN        NaN
# 5  72.829170  Mahārāshtra        NaN
# 6  72.827873  Mahārāshtra        NaN
# 7  72.828900  Mahārāshtra     400020
# 8  72.828754          NaN        NaN

# %%
dfc=dfc.drop(dfc.index[6])
dfc
# Out:
#                    name           categories  \
# 0     Metro Big Cinemas            Multiplex
# 1  New Excelsior Cinema        Movie Theater
# 2     New Empire Cinema  Indie Movie Theater
# 3        Liberty cinema  Indie Movie Theater
# 4   Metro Cinema Signal                 Road
# 5         Edward Cinema        Movie Theater
# 7    Metro Inox Cinemas            Multiplex
# 8     metro big cinemas           Auditorium
#
#                               address                crossStreet        lat  \
# 0  Anandilal Podar Marg, Marine Lines  Opp Cowasji Jehangir Hall  18.943304
# 1                                 NaN                        NaN  18.937665
# 2                                 NaN                        NaN  18.938708
# 3                  41/42 Marine Lines                        NaN  18.941652
# 4                                 NaN                        NaN  18.944518
# 5                     Kalabadevi Road                        NaN  18.945142
# 7                      metro Junction               Marine lines  18.943236
# 8                                 NaN                        NaN  18.943835
#
#          lng        state postalCode
# 0  72.828897  Mahārāshtra        NaN
# 1  72.833533  Mahārāshtra        NaN
# 2  72.834271          NaN        NaN
# 3  72.827389  Mahārāshtra        NaN
# 4  72.829701          NaN        NaN
# 5  72.829170  Mahārāshtra        NaN
# 7  72.828900  Mahārāshtra     400020
# 8  72.828754          NaN        NaN

# %%
dfc['address'] =dfc['address'].replace(np.nan,'South Mumbai')

# %%
dfc
# Out:
#                    name           categories  \
# 0     Metro Big Cinemas            Multiplex
# 1  New Excelsior Cinema        Movie Theater
# 2     New Empire Cinema  Indie Movie Theater
# 3        Liberty cinema  Indie Movie Theater
# 4   Metro Cinema Signal                 Road
# 5         Edward Cinema        Movie Theater
# 7    Metro Inox Cinemas            Multiplex
# 8     metro big cinemas           Auditorium
#
#                               address                crossStreet        lat  \
# 0  Anandilal Podar Marg, Marine Lines  Opp Cowasji Jehangir Hall  18.943304
# 1                        South Mumbai                        NaN  18.937665
# 2                        South Mumbai                        NaN  18.938708
# 3                  41/42 Marine Lines                        NaN  18.941652
# 4                        South Mumbai                        NaN  18.944518
# 5                     Kalabadevi Road                        NaN  18.945142
# 7                      metro Junction               Marine lines  18.943236
# 8                        South Mumbai                        NaN  18.943835
#
#          lng        state postalCode
# 0  72.828897  Mahārāshtra        NaN
# 1  72.833533  Mahārāshtra        NaN
# 2  72.834271          NaN        NaN
# 3  72.827389  Mahārāshtra        NaN
# 4  72.829701          NaN        NaN
# 5  72.829170  Mahārāshtra        NaN
# 7  72.828900  Mahārāshtra     400020
# 8  72.828754          NaN        NaN

# %%
df_cinema=dfc

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_cinema, df_cafeteria, df_park,df_restaurant], ignore_index=True)
hotel_neighbourhood_df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                               address            categories  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...                 Hotel
# 1                                26, ADI Marzban Path       Bed & Breakfast
# 2                                        South Mumbai                 Hotel
# 3                                        South Mumbai                 Hotel
# 4             panthaky house, Raghunath dadaji street     Indian Restaurant
# ..                                                ...                   ...
# 75                                          Mint Road             BBQ Joint
# 76                                       South Mumbai            Irani Cafe
# 77                                       South Mumbai  Cantonese Restaurant
# 78                                       South Mumbai            Restaurant
# 79                          B Block, Sitaram Building                Lounge
#
#    crossStreet        lat        lng                    name postalCode  \
# 0          NaN  18.934978  72.833481         Residency Hotel     400001
# 1          NaN  18.936039  72.838000   Hotel Traveller’s Inn     400001
# 2          NaN  18.938970  72.835610       City Palace Hotel     400101
# 3          NaN  18.938211  72.835725             sheel hotel     400101
# 4          NaN  18.935671  72.834030    Hotel Fountain Plaza     400101
# ..         ...        ...        ...                     ...        ...
# 75         NaN  18.935266  72.837240  Excellensea Restaurant     400001
# 76         NaN  18.935040  72.836941       Kayani Restaurant     400101
# 77         NaN  18.937876  72.831005  Royal China Restaurant     400101
# 78         NaN  18.935007  72.833687     Brighton Restaurant     400101
# 79         NaN  18.945482  72.834270      Ustaadi Restaurant     400001
#
#           state
# 0   Maharashtra
# 1   Maharashtra
# 2   Maharashtra
# 3   Maharashtra
# 4   Maharashtra
# ..          ...
# 75  Maharashtra
# 76  Maharashtra
# 77  Maharashtra
# 78  Maharashtra
# 79  Maharashtra
#
# [80 rows x 8 columns]

# %% [markdown]
# ### Visualize all the Data

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # END
